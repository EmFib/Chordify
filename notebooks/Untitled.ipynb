# %%
import nltk
import string
import numpy as np
import pandas as pd
from nltk.stem.wordnet import WordNetLemmatizer
from collections import Counter
from nltk.corpus import stopwords
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/emilynaftalin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/emilynaftalin/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
pwd
# Out:
# '/Users/emilynaftalin/galvanize/dsi/capstone/Guitar-Chord-Generator/notebooks'

# %%
cd ..
# Out:
# /Users/emilynaftalin/galvanize/dsi/capstone/Guitar-Chord-Generator

# %%
from src.parse import *

# %%
from src import load_song_data

# %%
# %run src/load_song_data.py
# Out:
# ......................................................................................................................................
# /Users/emilynaftalin/galvanize/dsi/capstone/Guitar-Chord-Generator/src/parse.py:124: UserWarning: Bad song.
#   warnings.warn(str(e))
# ...

# %%
df
# Out:
#       contains_minor                                             lyrics
# 0               True  As I went out one morning to breathe the air a...
# 1               True  As I went out one morning to breathe the air a...
# 2               True  As I went out one morning to breathe the air a...
# 3               True  As I went out one morning to breathe the air a...
# 4               True  One by one they followed the sun One by one un...
# 5              False  I went to the doctor he says I'm alright I kne...
# 6              False  When she said Don't waste your words they're j...
# 7              False  Take a trip with me in 1913 To Calumet Michiga...
# 8               True  One by one they followed the sun One by one un...
# 9              False  I went to the doctor he says I'm alright I kne...
# 10             False  When she said Don't waste your words they're j...
# 11              True  Well I m down here on this track Not a shirt u...
# ...

# %%
lemmatize = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def clean_lyrics(doc):
    doc_no_stopwords = " ".join([i for i in doc.lower().split() if i not in stop_words])
#     doc_no_punctuation = "".join(i for i in doc_no_stopwords if i not in punctuation)
    doc_Lemmatized = " ".join(lemmatize(i) for i in doc_no_stopwords.split())
    return doc_Lemmatized

def create_bows(df):
    df['bow'] = df['lyrics'].apply(lambda x: clean_lyrics(x))
    return df

# %%
create_bows(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-5ae3534bfabe> in <module>()
# ----> 1 create_bows(df)
#
# <ipython-input-47-c1005f74edb0> in create_bows(df)
#       9
#      10 def create_bows(df):
# ---> 11     df['bow'] = df['lyrics'].apply(lambda x: clean_lyrics(x))
#      12     return df
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-47-c1005f74edb0> in <lambda>(x)
#       9
#      10 def create_bows(df):
# ...
